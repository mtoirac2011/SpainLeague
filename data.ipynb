# %%
import pandas as pd

# %%
#reading csv file and listing first items
rm_players = pd.read_csv("real_madrid_fc.csv")
rm_players.head(25)
# Out:
#                Player   Nation    Pos     Age  MP  Starts    Min   90s   Gls  \
# 0    Thibaut Courtois   be BEL     GK  29-275  23      23  2,070  23.0   0.0
# 1        Eder Militao   br BRA     DF  24-023  22      22  1,980  22.0   1.0
# 2         David Alaba   at AUT     DF  29-231  21      21  1,882  20.9   1.0
# 3       Karim Benzema   fr FRA     FW  34-053  21      21  1,703  18.9  17.0
# 4     Vinicius Junior   br BRA  FW,MF  21-213  21      19  1,688  18.8  12.0
# 5            Casemiro   br BRA     MF  29-352  20      19  1,670  18.6   0.0
# 6          Toni Kroos   de GER     MF  32-037  16      16  1,345  14.9   1.0
# 7          Luka Modri   hr CRO     MF  36-154  16      16  1,271  14.1   1.0
# 8       Ferland Mendy   fr FRA     DF  26-247  14      13  1,119  12.4   1.0
# 9       Lucas Vazquez   es ESP     DF  30-224  17      11  1,045  11.6   1.0
# 10      Marco Asensio   es ESP  FW,MF  26-020  18      11    994  11.0   6.0
# ...

# %%
#Exploring size of data 
rm_players.shape
# Out:
# (35, 29)

# %%
#Exploring columns of data 
rm_players.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Age', 'MP', 'Starts', 'Min', '90s', 'Gls',
#        'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls.1', 'Ast.1', 'G+A',
#        'G-PK.1', 'G+A-PK', 'xG', 'npxG', 'xA', 'npxG+xA', 'xG.1', 'xA.1',
#        'xG+xA', 'npxG.1', 'npxG+xA.1'],
#       dtype='object')

# %%
#Exploring null data 
rm_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Player     35 non-null     object
#  1   Nation     35 non-null     object
#  2   Pos        35 non-null     object
#  3   Age        35 non-null     object
#  4   MP         35 non-null     int64
#  5   Starts     35 non-null     int64
#  6   Min        28 non-null     object
#  7   90s        28 non-null     float64
#  8   Gls        28 non-null     float64
#  9   Ast        28 non-null     float64
#  10  G-PK       28 non-null     float64
#  11  PK         28 non-null     float64
#  12  PKatt      28 non-null     float64
#  13  CrdY       28 non-null     float64
#  14  CrdR       28 non-null     float64
#  15  Gls.1      28 non-null     float64
#  16  Ast.1      28 non-null     float64
#  17  G+A        28 non-null     float64
#  18  G-PK.1     28 non-null     float64
# ...

# %%
#Exploring descripcion of data 
rm_players.describe()
# Out:
#               MP     Starts        90s        Gls        Ast       G-PK  \
# count  35.000000  35.000000  28.000000  28.000000  28.000000  28.000000
# mean    9.828571   7.114286   8.928571   1.714286   1.250000   1.607143
# std     8.459195   8.013854   7.623252   3.857241   1.797632   3.583287
# min     0.000000   0.000000   0.100000   0.000000   0.000000   0.000000
# 25%     1.000000   0.000000   1.950000   0.000000   0.000000   0.000000
# 50%    12.000000   3.000000   8.450000   1.000000   0.500000   0.500000
# 75%    17.000000  12.000000  14.300000   1.000000   2.000000   1.000000
# max    23.000000  23.000000  23.000000  17.000000   7.000000  15.000000
#
#               PK      PKatt       CrdY  CrdR  ...     G+A-PK         xG  \
# count  28.000000  28.000000  28.000000  28.0  ...  28.000000  28.000000
# mean    0.107143   0.142857   1.500000   0.0  ...   0.277143   1.535714
# std     0.416270   0.590937   1.815571   0.0  ...   0.321015   2.668779
# ...
